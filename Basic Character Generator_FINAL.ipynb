# %%
import random
import pandas as pd
import numpy as np
#Create the paramenters for dice Rolling

def N_Dice():
    Number_Dice = int(input('How many Dice would you like to roll?'))
    if Number_Dice <=100:
        return Number_Dice
    else:
        print('Thats too many dice')
x= N_Dice()


def N_Dice_Sides():
    Number_Dice_Sides = int(input('How many sides will your dice have?'))
    if Number_Dice_Sides <=20:
        return Number_Dice_Sides
    else:
        print('Too many sides.')
y= N_Dice_Sides()

def STR():
    Rolled_Dice_STR=(random.randint(x,(x*y)))
    while Rolled_Dice_STR <=7:
        Rolled_Dice_STR=(random.randint(x,(x*y)))
    return Rolled_Dice_STR

STR = STR()

print(STR)

def CHA():
    Rolled_Dice_CHA=(random.randint(x,(x*y)))
    while Rolled_Dice_CHA <=7:
        Rolled_Dice_CHA=(random.randint(x,(x*y)))
    return Rolled_Dice_CHA

CHA = CHA()

print(CHA)

def DEX():
    Rolled_Dice_DEX=(random.randint(x,(x*y)))
    while Rolled_Dice_DEX <=7:
        Rolled_Dice_DEX=(random.randint(x,(x*y)))
    return Rolled_Dice_DEX

DEX = DEX()

print(DEX)

def CON():
    Rolled_Dice_CON=(random.randint(x,(x*y)))
    while Rolled_Dice_CON <=7:
        Rolled_Dice_CON=(random.randint(x,(x*y)))
    return Rolled_Dice_CON

CON = CON()

print(CON)

def INT():
    Rolled_Dice_INT=(random.randint(x,(x*y)))
    while Rolled_Dice_INT <=7:
        Rolled_Dice_INT=(random.randint(x,(x*y)))
    return Rolled_Dice_INT

INT = INT()

print(INT)

def WIS():
    Rolled_Dice_WIS=(random.randint(x,(x*y)))
    while Rolled_Dice_WIS <=7:
        Rolled_Dice_WIS=(random.randint(x,(x*y)))
    return Rolled_Dice_WIS

WIS = WIS()

print(WIS)

def Race():
    Race = str(input('What race are you?'))
    return Race

Race = Race()

if Race == "Dwarf":
    STR = STR + 2
    CHA = CHA - 2
    WIS = WIS + 2
elif Race == "Elf":
    DEX = DEX + 2
    INT = INT + 2
    CON = CON - 2
elif Race == "Gnome":
    CON = CON + 2
    CHA = CHA + 2
    STR = STR - 2
elif Race == 'Half-Elf':
    Half_Elf = str(input('Which ABS do you want to increase?'))
    if Half_Elf == 'STR':
        STR = STR + 2
    elif Half_Elf == 'CHA':    
        CHA = CHA + 2
    elif Half_Elf == 'DEX':
        DEX = DEX + 2
    elif Half_Elf == 'CON':
        CON = CON + 2
    elif Half_Elf == 'INT':
        INT = INT + 2
    elif Half_Elf == 'WIS':
        WIS = WIS + 2
elif Race == 'Half-Orc':
    Half_Orc = str(input('Which ABS do you want to increase?'))
    if Half_Orc == 'STR':
        STR = STR + 2
    elif Half_Orc == 'CHA':    
        CHA = CHA + 2
    elif Half_Orc == 'DEX':
        DEX = DEX + 2
    elif Half_Orc == 'CON':
        CON = CON + 2
    elif Half_Orc == 'INT':
        INT = INT + 2
    elif Half_Orc == 'WIS':
        WIS = WIS + 2
elif Race == "Human":
    Human = str(input('Which ABS do you want to increase?'))
    if Human == 'STR':
        STR = STR + 2
    elif Human == 'CHA':
        CHA = CHA + 2
    elif Human == 'DEX':
        DEX = DEX + 2
    elif Human == 'CON':
        CON = CON + 2
    elif Human == 'INT':
        INT = INT + 2
    elif Human == 'WIS':
        WIS = WIS + 2
elif Race == "Halfling":
    DEX = DEX + 2
    CHA = CHA + 2
    STR = STR - 2
else:
    print("Unknown Race.")

if Race == "Dwarf":
    Size = "Medium"
elif Race == "Elf":
    Size = "Medium"
elif Race == "Gnome":
    Size = "Small"
elif Race == "Half-Elf":
    Size = "Medium"
elif Race == "Half-Orc":
    Size = "Medium"
elif Race == "Halfling":
    Size ="Small"
elif Race == "Human":
    Size = "Medium"
else:
    print("Ginormous!")

def Gender():
    Gender = (random.randint(1,2))
    if Gender == 1:
        Gender = "Male"
    else:
        Gender = "Female"
    return Gender

Gender = Gender()

if Race == "Human":
    Age = (random.randint(16,50))
elif Race == "Dwarf":
    Age = (random.randint(50,250))
elif Race == "Gnome":
    Age = (random.randint(50,250))
elif Race == "Elf":
    Age = (random.randint(100,400))
elif Race == "Half-Elf":
    Age = (random.randint(20,200))
elif Race == "Half-Orc":
    Age = (random.randint(14,50))
elif Race == "Halfling":
    Age = (random.randint(18,50))
else: 
    print('How old are you?')
    
def Eye_Color():
    Colors = ["Blue", "Green", "Yellow", "Brown", "Hazel", "Black"]
    Eye_Color = (random.randint(0,(len(Colors)-1)))
    return Colors[Eye_Color] 
    
Eye_Color = Eye_Color()
    
def Hair_Color():
    Colors = ["Blue", "Green", "Yellow", "Brown", "Black", "Blonde", "Platinum","Rainbow","Silver"]
    Hair_Color = (random.randint(0,(len(Colors)-1)))
    return Colors[Hair_Color]

Hair_Color = Hair_Color()


Pathfinder_Languages = ["Dwarven", "Abyssal", "Aklo", "Acquan", "Auran", "Celestial","Draconic", "Druidic", "Elven",
                            "Giant", "Gnomish", "Goblin", "Gnoll", "Halfling", "Ignan","Infernal", "Orcish", "Sylvan",
                           "Terran", "Undercommon"]
Dwarven_Languages = ["Abyssal", "Aklo", "Acquan", "Auran", "Celestial","Draconic", "Druidic", "Elven",
                            "Giant", "Gnomish", "Goblin", "Gnoll", "Halfling", "Ignan","Infernal", "Orcish", "Sylvan",
                           "Terran", "Undercommon"]
Elvish_Languages = ["Dwarven", "Abyssal", "Aklo", "Acquan", "Auran", "Celestial","Draconic", "Druidic",
                            "Giant", "Gnomish", "Goblin", "Gnoll", "Halfling", "Ignan","Infernal", "Orcish", "Sylvan",
                           "Terran", "Undercommon"]
Gnomish_Languages = ["Dwarven", "Abyssal", "Aklo", "Acquan", "Auran", "Celestial","Draconic", "Druidic", "Elven",
                            "Giant", "Goblin", "Gnoll", "Halfling", "Ignan","Infernal", "Orcish", "Sylvan",
                           "Terran", "Undercommon"]
Halfling_Languages = ["Dwarven", "Abyssal", "Aklo", "Acquan", "Auran", "Celestial","Draconic", "Druidic", "Elven",
                            "Giant", "Gnomish", "Goblin", "Gnoll", "Ignan","Infernal", "Orcish", "Sylvan",
                           "Terran", "Undercommon"]
Orcish_Languages = ["Dwarven", "Abyssal", "Aklo", "Acquan", "Auran", "Celestial","Draconic", "Druidic", "Elven",
                            "Giant", "Gnomish", "Goblin", "Gnoll", "Halfling", "Ignan","Infernal", "Sylvan",
                           "Terran", "Undercommon"]

common = "Common"

def Human_Languages(Race, racial_string,language_list):
    if Race == racial_string and INT <= 11:
        Languages = common
    elif Race == racial_string and INT <= 13:
        Languages = common, random.sample(language_list,1)
    elif Race == racial_string and INT <= 15:
        Languages = common, random.sample(language_list,2)
    elif Race == racial_string and INT <= 17:
        Languages = common, random.sample(language_list,3)
    elif Race == racial_string and INT <= 19:
        Languages = common, random.sample(language_list,4)
    elif Race == racial_string and INT <= 21:
        Languages = common, random.sample(language_list,5)
    return Languages

def Other_Races_Languages(Race, racial_language1, language_list):
    if Race == Race and INT <= 11:
        Languages = Race
    elif Race == Race and INT <= 13:
        Languages = common, racial_language1, random.sample(language_list,1)
    elif Race == Race and INT <= 15:
        Languages = common, racial_language1, random.sample(language_list,2)
    elif Race == Race and INT <= 17:
        Languages = common, racial_language1, random.sample(language_list,3)
    elif Race == Race and INT <= 19:
        Languages = common, racial_language1, random.sample(language_list,4)
    elif Race == Race and INT <= 21:
        Languages = common, racial_language1, random.sample(language_list,5)
    return Languages

def Languages():
    if Race == "Human":
        Languages = Human_Languages(Race, Race, Pathfinder_Languages)
    elif Race == "Dwarf":
        Languages = Other_Races_Languages(Race, "Dwarven", Dwarven_Languages)
    elif Race == "Gnome":
        Languages = Other_Races_Languages(Race, "Gnomish", Gnomish_Languages)
    elif Race == "Elf":
        Languages = Other_Races_Languages(Race, "Elven", Elvish_Languages)
    elif Race == "Half-Elf":
        Languages = Other_Races_Languages(Race, "Elven", Elvish_Languages)
    elif Race == "Half-Orc":
        Languages = Other_Races_Languages(Race, "Orcish", Orcish_Languages)
    elif Race == "Halfling":
        Languages = Other_Races_Languages(Race, "Halfling", Halfling_Languages)
    else:
        print("Error")
    return Languages

    
Languages = Languages()

def Height():
    if Race == "Human":
        Inches = (random.randint(1,12))
        Feet = (random.randint(4,7))*12
        Height = Inches + Feet
        Height /= 12
    elif Race == "Dwarf":
        Inches = (random.randint(1,12))
        Feet = (random.randint(3,4))*12
        Height = Inches + Feet
        Height /= 12
    elif Race == "Gnome":
        Inches = (random.randint(1,12))
        Feet = (3*12)
        Height = Inches + Feet
        Height /= 12
    elif Race == "Elf":
        Inches = (random.randint(1,12))
        Feet = (random.randint(6,7))*12
        Height = Inches + Feet
        Height /= 12
    elif Race == "Half-Elf":
        Inches = (random.randint(1,12))
        Feet = (random.randint(6,7))*12
        Height = Inches + Feet
        Height /= 12
    elif Race == "Half-Orc":
        Inches = (random.randint(1,12))
        Feet = (random.randint(7,8))*12
        Height = Inches + Feet
        Height /= 12
    elif Race == "Halfling":
        Inches = (random.randint(1,12))
        Feet = (random.randint(1,3))*12
        Height = Inches + Feet
        Height /= 12
    else: 
        print('How tall are you?')
    return Height

Height = Height()
        
def Weight():
    if Race == "Human":
        Weight = (random.randint(100,190))
    elif Race == "Dwarf":
        Weight = (random.randint(150,200))
    elif Race == "Gnome":
        Weight = (random.randint(50,100))
    elif Race == "Elf":
        Weight = (random.randint(100,150))
    elif Race == "Half-Elf":
        Weight = (random.randint(100,150))
    elif Race == "Half-Orc":
        Weight = (random.randint(225,300))
    elif Race == "Halfling":
        Weight = (random.randint(50,75))
    else:
        print("How much do you weigh?")
    return Weight

Weight = Weight()

## STILL MUST UPDATE THE ELF, HALF ELF, HALFLING AND HALF-ORC NAMES
Dwarf_Male_First_Names = ["Dolgrin", "Grunyar", "Harsk", "Kazmuk", "Morgym", "Rogar", "Redan"]
Dwarf_Female_First_Names = ["Agna","Bodil", "Ingra", "Kotri","Rusilka", "Yangrit"]
Dwarf_Last_Names = ["Brandbeard", "Stonefist", "Grim-Jaw", "Ironheart"]
Human_Male_First_Names = ["John", "Paul", "James", "Tsukan", "Rill", "Jim", "Olliver", "Bruce", "Jiyan"]
Human_Female_First_Names = ["Kara","Jin", "Olan", "Arella","Misty", "Tisra"]
Human_Last_Names = ["Miller", "Adar", "Jillan", "Ironheart", "Merrick", "Kessel","Yar"]
Gnome_Male_First_Names = ["Abroshtor", "Bastagre", "Halungalon", "Krolmnite", "Poshment", "Zarzuket", "Zatqualmie"]
Gnome_Female_First_Names = ["Besh", "Fijit", "Lini", "Neji", "Majet", "Pai", "Queck", "Trig"]
Gnome_Last_Names = ["Erondar", "Sprixlswocket", "Zatlegen", "Biom", "Topag", "Qropswunass"]
Elf_Male_First_Names = ["Abroshtor", "Bastagre", "Halungalon", "Krolmnite", "Poshment", "Zarzuket", "Zatqualmie"]
Elf_Female_First_Names = ["Besh", "Fijit", "Lini", "Neji", "Majet", "Pai", "Queck", "Trig"]
Elf_Last_Names = ["Erondar", "Sprixlswocket", "Zatlegen", "Biom", "Topag", "Qropswunass"]
Half_Elf_Male_First_Names = ["Abroshtor", "Bastagre", "Halungalon", "Krolmnite", "Poshment", "Zarzuket", "Zatqualmie"]
Half_Elf_Female_First_Names = ["Besh", "Fijit", "Lini", "Neji", "Majet", "Pai", "Queck", "Trig"]
Half_Elf_Last_Names = ["Erondar", "Sprixlswocket", "Zatlegen", "Biom", "Topag", "Qropswunass"]
Halfling_Male_First_Names = ["Abroshtor", "Bastagre", "Halungalon", "Krolmnite", "Poshment", "Zarzuket", "Zatqualmie"]
Halfling_Female_First_Names = ["Besh", "Fijit", "Lini", "Neji", "Majet", "Pai", "Queck", "Trig"]
Halfling_Last_Names = ["Erondar", "Sprixlswocket", "Zatlegen", "Biom", "Topag", "Qropswunass"]
Half_Orc_Male_First_Names = ["Abroshtor", "Bastagre", "Halungalon", "Krolmnite", "Poshment", "Zarzuket", "Zatqualmie"]
Half_Orc_Female_First_Names = ["Besh", "Fijit", "Lini", "Neji", "Majet", "Pai", "Queck", "Trig"]
Half_Orc_Last_Names = ["Erondar", "Sprixlswocket", "Zatlegen", "Biom", "Topag", "Qropswunass"]

def name(Race_String, Race_Gender_First_Name1, Race_Gender_First_Name2, Race_Last_Name):
    if Race == Race_String and Gender == "Male":
        First_Name = Race_Gender_First_Name1[(random.randint(0,(len(Race_Gender_First_Name1)-1)))]
        Last_Name = Race_Last_Name[(random.randint(0,(len(Race_Last_Name)-1)))]
        return First_Name, Last_Name
    elif Race == Race_String and Gender == "Female":
        First_Name = Race_Gender_First_Name2[(random.randint(0,(len(Race_Gender_First_Name2)-1)))]
        Last_Name = Race_Last_Name[(random.randint(0,(len(Race_Last_Name)-1)))]
        return First_Name, Last_Name
    else:
        print('error')

if Race == "Human":
    Names = name("Human", Human_Male_First_Names, Human_Female_First_Names, Human_Last_Names)
elif Race == "Dwarf":
    Names = name("Dwarf", Dwarf_Male_First_Names, Dwarf_Female_First_Names, Dwarf_Last_Names)
elif Race == "Gnome":
    Names = name("Gnome", Gnome_Male_First_Names, Gnome_Female_First_Names, Gnome_Last_Names)
elif Race == "Halfling":
    Names = name("Halfling", Halfling_Male_First_Names, Halfling_Female_First_Names,  Halfling_Last_Names)
elif Race == "Elf":
    Names = name("Elf", Elf_Male_First_Names, Elf_Female_First_Names, Elf_Last_Names)
elif Race == "Half-Orc":
    Names = name("Half-Orc", Half_Orc_Male_First_Names, Half_Orc_Female_First_Names, Half_Orc_Last_Names)
elif Race == "Half-Elf":
    Names = name("Half-Elf", Half_Elf_Male_First_Names, Half_Elf_Female_First_Names, Half_Elf_Last_Names)
else:
    print("error")
    
    

Names





Class = ['Barbarian', 'Bard', 'Cleric','Druid', 'Fighter', 'Monk', 'Paladin', 'Ranger', 'Rogue', 'Sorcerer', 'Wizard']
Rand_Class = Class[(random.randint(0,(len(Class)-1)))]
                  
ABS = Names, Rand_Class, Race, STR, CHA, DEX, CON, INT, WIS, Size, Gender, Age, Eye_Color, Hair_Color, Languages, Height, Weight
Ability_Scores = []
Ability_Scores = pd.DataFrame(Ability_Scores, columns = 
                              ["Name","Class","Race", "Strength", "Charisma", "Dexterity", "Constitution", "Intelligence", 
                               "Wisdom", "Size", "Gender","Age", "Eye Color", "Hair Color", "Languages", "Height", 
                               "Weight"])
ABS = pd.Series([Names, Rand_Class, Race,STR,CHA,DEX,CON,INT,WIS, Size, Gender,Age, Eye_Color, Hair_Color, Languages, Height, 
                 Weight], index = Ability_Scores.columns)
Ability_Scores = pd.DataFrame(ABS)
Ability_Scores= Ability_Scores.T

Ab_Scores = STR, CHA, DEX, CON, INT, WIS
Modifiers= []

##Checking for odd or even numbers to get a whole number modifier using the modulous % and dividng by 2 to check for 
##a remainder if >0 then odd number

for x in Ab_Scores:
    if x %2 > 0:
        x = ((x-11)/2)
    else:
        x = ((x-10)/2)
    Modifiers.append(x)

    
Str_Mod = Modifiers[0]
Cha_Mod = Modifiers[1]
Dex_Mod = Modifiers[2]
Con_Mod = Modifiers[3]
Int_Mod = Modifiers[4]
Wis_Mod = Modifiers[5]

Modifiers = [Str_Mod, Dex_Mod, Wis_Mod, Cha_Mod, Con_Mod, Int_Mod]
Ability_Mod = []
Ability_Mod = pd.DataFrame(Ability_Mod, columns = 
                              ["Str Mod", "Dex Mod", "Wis Mod", "Cha Mod", "Con Mod", "Int Mod"])
Modifiers = pd.Series([Str_Mod, Dex_Mod, Wis_Mod, Cha_Mod, Con_Mod, Int_Mod], index = Ability_Mod.columns)
Ability_Mod = pd.DataFrame(Modifiers)
Ability_Mod = Ability_Mod.T
print(Ability_Mod)



if Rand_Class == 'Barbarian':
    Skill_Ranks = 4 + Int_Mod
elif Rand_Class == 'Bard':
    Skill_Ranks = 4 + Int_Mod
elif Rand_Class == 'Cleric':
    Skill_Ranks = 2 + Int_Mod
elif Rand_Class == "Druid":
    Skill_Ranks = 4 + Int_Mod
elif Rand_Class =="Fighter":
    Skill_Ranks = 2 + Int_Mod
elif Rand_Class =="Monk":
    Skill_Ranks = 4 + Int_Mod
elif Rand_Class =="Paladin":
    Skill_Ranks = 2 + Int_Mod
elif Rand_Class =="Ranger":
    Skill_Ranks = 6 + Int_Mod
elif Rand_Class =="Rogue":
    Skill_Ranks = 8 + Int_Mod
elif Rand_Class =="Sorcerer":
    Skill_Ranks = 2 + Int_Mod
elif Rand_Class =="Wizard":
    Skill_Ranks = 2 + Int_Mod
else:
    print("Useless.")
Skill_Ranks = int(Skill_Ranks)    


class_skill = 3
    
skills_dict = {
"Acrobatics" : Dex_Mod,
"Appraise" : Int_Mod, 
"Bluff" : Cha_Mod,
"Climb" : Str_Mod,
"Craft": Int_Mod,
"Diplomacy" : Cha_Mod,
"Disable_Device" : Dex_Mod,
"Disguise" : Cha_Mod,
"Escape_Artist" : Dex_Mod,
"Fly" : Dex_Mod, 
"Handle_Animal" : Cha_Mod,
"Heal" : Wis_Mod,
"Intimidate" : Cha_Mod, 
"Knowledge_Arcana" : Int_Mod, 
"Knowledge_Dungeoneering" : Int_Mod, 
"Knowledge_Engineering" : Int_Mod, 
"Knowledge_Geography" : Int_Mod,
"Knowledge_History" : Int_Mod,
"Knowledge_Local": Int_Mod,
"Knowledge_Nature ": Int_Mod,
"Knowledge_Nobility" : Int_Mod,
"Knowledge_Planes" : Int_Mod, 
"Knowledge_Religion" : Int_Mod, 
"Linguistics" : Int_Mod,
"Perception" : Wis_Mod,
"Perform" : Cha_Mod,
"Profession"  : Wis_Mod,
"Ride" : Dex_Mod,
"Sense_Motive"  : Wis_Mod,
"Sleight_of_Hand" : Dex_Mod, 
"Spellcraft" : Int_Mod,   
"Stealth" : Dex_Mod,   
"Survival" : Wis_Mod,
"Swim": Str_Mod,
"Use_Magic_Device" : Cha_Mod}



barbarian_skills_dict ={"Acrobatics" : class_skill, "Climb" : class_skill, "Craft" : class_skill, 
                        "Handle_Animal" : class_skill, 
                         "Intimidate":  class_skill, "Knowledge_Nature" :  class_skill, "Perception": class_skill, 
                         "Ride":  class_skill, "Survival":  class_skill, "Swim" : class_skill}
bard_skills_dict ={"Acrobatics":  class_skill, "Appraise" : class_skill, "Bluff" : class_skill, 
                    "Climb" : class_skill, "Craft": class_skill, "Diplomacy": class_skill, "Disguise": class_skill, 
                    "Escape_Artist" : class_skill, "Intimidate" : class_skill, "Knowledge_Arcana" : class_skill, 
                    "Knowledge_Dungeoneering" : class_skill, "Knowledge_Engineering" : class_skill, 
      "Knowledge_Geography" : class_skill, "Knowledge_History" : class_skill, "Knowledge_Local" : class_skill, 
                    "Knowledge_Nature" : class_skill, "Knowledge_Nobility" : class_skill, 
       "Knowledge_Planes" : class_skill, "Knowledge_Religion" : class_skill, 
                    "Linguistics" : class_skill, "Perception": class_skill, "Perform" : class_skill, 
                    "Profession" : class_skill, "Sense_Motive" : class_skill, 
                    "Sleight_of_Hand" : class_skill, "Spellcraft" : class_skill, "Stealth" : class_skill, 
                    "Use_Magic_Device" : class_skill}
cleric_skills_dict = {"Appraise" : class_skill, "Craft": class_skill, "Diplomacy" : class_skill, 
                       "Heal" : class_skill, "Knowledge_Arcana" : class_skill, "Knowledge_History": class_skill, 
                       "Knowledge_Nobility": class_skill, "Knowledge_Planes" : class_skill,
                      "Knowledge_Religion" : class_skill, "Linguistics": class_skill, 
                       "Profession": class_skill, "Sense_Motive": class_skill, "Spellcraft" : class_skill}
druid_skills_dict = {"Climb" : class_skill, "Craft" : class_skill, "Fly": class_skill, 
                      "Handle_Animal": class_skill, "Heal" : class_skill, "Knowledge_Geography" : class_skill, 
                     "Knowledge_Nature": class_skill, "Perception": class_skill,
                     "Profession": class_skill, "Ride": class_skill, "Spellcraft" : class_skill, 
                      "Survival": class_skill, "Swim": class_skill}
fighter_skills_dict ={"Climb": class_skill, "Craft": class_skill, "Handle_Animal": class_skill, 
                       "Intimidate": class_skill, "Knowledge_Dungeoneering": class_skill, 
                       "Knowledge_Engineering": class_skill, "Profession": class_skill, "Ride": class_skill, 
                       "Survival": class_skill, "Swim": class_skill}
monk_skills_dict = {"Acrobatics": class_skill, "Climb": class_skill, "Craft": class_skill, 
                     "Escape_Artist": class_skill, "Intimidate": class_skill, 
                     "Knowledge_History": class_skill, "Knowledge_Religion": class_skill, "Perception": class_skill, 
                     "Perform": class_skill, "Profession": class_skill, "Ride": class_skill, 
                     "Sense_Motive": class_skill, "Stealth": class_skill, "Swim": class_skill}
paladin_skills_dict = {"Craft": class_skill, "Diplomacy": class_skill, "Handle_Animal": class_skill, 
                        "Heal": class_skill, "Knowledge_Nobility": class_skill, "Knowledge_Religion": class_skill, 
                        "Profession": class_skill, "Ride": class_skill, 
                        "Sense_Motive": class_skill, "Spellcraft": class_skill}
ranger_skills_dict = {"Climb": class_skill, "Craft": class_skill, "Handle_Animal": class_skill, "Heal": class_skill, 
                       "Intimidate": class_skill, "Knowledge_Dungeoneering": class_skill, 
                       "Knowledge_Geography": class_skill, 
                       "Knowledge_Nature": class_skill, "Perception": class_skill, "Profession": class_skill, 
                       "Ride": class_skill, "Spellcraft": class_skill, "Stealth": class_skill, 
                       "Survival": class_skill, "Swim": class_skill}

rogue_skills_dict = {'Acrobatics': class_skill, 'Appraise' : class_skill, 'Bluff': class_skill, 'Climb': class_skill, 
                     'Craft':class_skill, 'Diplomacy': class_skill, 
                     'Disable_Device' :class_skill, 'Disguise': class_skill, 'Escape_Artist': class_skill, 
                      'Intimidate' : class_skill, 'Knowledge_Dungeoneering' :class_skill, 
                     'Knowledge_Local': class_skill, 'Linguistics' : class_skill, 'Perception': class_skill, 
                     'Perform': class_skill, 'Profession' : class_skill, 
                      'Sense_Motive': class_skill, 'Sleight_of_Hand': class_skill, 
                     'Stealth': class_skill, 'Swim':class_skill, 'Use_Magic_Device': class_skill}

sorcerer_skills_dict = {"Appraise" : class_skill, "Bluff": class_skill, "Craft": class_skill, 
                         "Fly": class_skill, "Intimidate" : class_skill, "Knowledge_Arcana" : class_skill, 
                         "Profession": class_skill, "Spellcraft" : class_skill, "Use_Magic_Device": class_skill}
wizard_skills_dict = {"Appraise" : class_skill, "Craft" : class_skill, "Fly" : class_skill, "Knowledge_Arcana": class_skill, 
                       "Knowledge_Dungeoneering" : class_skill, "Knowledge_Engineering" : class_skill, 
      "Knowledge_Geography" : class_skill, "Knowledge_History" : class_skill, "Knowledge_Local" : class_skill, 
                       "Knowledge_Nature" : class_skill, "Knowledge_Nobility" : class_skill, 
       "Knowledge_Planes" : class_skill, 
                       "Knowledge_Religion" : class_skill, "Linguistics" : class_skill, "Profession" : class_skill, 
                       "Spellcraft" : class_skill}

## Setting if statement up to compare lists and then add in class skills based off the randomized class
if Class == "Barbarian":
    for key in skills_dict:
        if key in barbarian_skills_dict:
            skills_dict[key] = skills_dict[key] + barbarian_skills_dict[key]                                                 
        else:
            print("list_compare error")
elif Class == "Bard":
    for key in skills_dict:
        if key in bard_skills_dict:
            skills_dict[key] = skills_dict[key] + bard_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Cleric":
    for key in skills_dict:
        if key in cleric_skills_dict:
            skills_dict[key] = skills_dict[key] + cleric_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Druid":
    for key in skills_dict:
        if key in druid_skills_dict:
            skills_dict[key] = skills_dict[key] + druid_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Fighter":
    for key in skills_dict:
        if key in fighter_skills_dict:
            skills_dict[key] = skills_dict[key] + fighter_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Monk":
    for key in skills_dict:
        if key in monk_skills_dict:
            skills_dict[key] = skills_dict[key] + monk_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Paladin":
    for key in skills_dict:
        if key in paladin_skills_dict:
            skills_dict[key] = skills_dict[key] + paladin_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Ranger":
    for key in skills_dict:
        if key in ranger_skills_dict:
            skills_dict[key] = skills_dict[key] + ranger_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Rogue":
    for key in skills_dict:
        if key in rogue_skills_dict:
            skills_dict[key] = skills_dict[key] + rogue_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Sorcerer":
    for key in skills_dict:
        if key in sorcerer_skills_dict:
            skills_dict[key] = skills_dict[key] + sorcerer_skills_dict[key]                                                   
        else:
            print("list_compare error")
elif Class == "Wizard":
    for key in skills_dict:
        if key in wizard_skills_dict:
            skills_dict[key] = skills_dict[key] + wizard_skills_dict[key]                                                   
        else:
            print("list_compare error")

skills_list_name = []
skills_list_value = []
## Converting to a List. Need to separate values from the keys
for key, value in skills_dict.items():
    skills_list_name.append([key])
    skills_list_value.append([value])

Acrobatics = skills_list_value[0]
Appraise = skills_list_value[1]       
Bluff = skills_list_value[2]      
Climb = skills_list_value[3]      
Craft = skills_list_value[4]     
Diplomacy = skills_list_value[5]      
Disable_Device = skills_list_value[6]      
Disguise = skills_list_value[7]      
Escape_Artist = skills_list_value[8]      
Fly = skills_list_value[9]       
Handle_Animal = skills_list_value[10]      
Heal = skills_list_value[11]      
Intimidate = skills_list_value[12]       
Knowledge_Arcana = skills_list_value[13]       
Knowledge_Dungeoneering = skills_list_value[14]       
Knowledge_Engineering = skills_list_value[15]       
Knowledge_Geography = skills_list_value[16]      
Knowledge_History = skills_list_value[17]      
Knowledge_Local = skills_list_value[18]     
Knowledge_Nature = skills_list_value[19]      
Knowledge_Nobility = skills_list_value[20]      
Knowledge_Planes = skills_list_value[21]       
Knowledge_Religion = skills_list_value[22]       
Linguistics = skills_list_value[23]      
Perception = skills_list_value[24]      
Perform = skills_list_value[25]      
Profession = skills_list_value[26]       
Ride = skills_list_value[27]      
Sense_Motive = skills_list_value[28]       
Sleight_of_Hand = skills_list_value[29]       
Spellcraft = skills_list_value[30]         
Stealth = skills_list_value[31]         
Survival = skills_list_value[32]      
Swim = skills_list_value[33]      
Use_Magic_Device = skills_list_value[34]   


Skill_List = [Acrobatics,  Appraise, Bluff, Climb, Craft, Diplomacy, Disable_Device, Disguise, Escape_Artist, Fly,
      Handle_Animal, Heal, Intimidate, Knowledge_Arcana, Knowledge_Dungeoneering, Knowledge_Engineering, 
      Knowledge_Geography, Knowledge_History, Knowledge_Local, Knowledge_Nature, Knowledge_Nobility, 
       Knowledge_Planes, Knowledge_Religion, Linguistics, Perception, Perform, Profession, Ride, 
       Sense_Motive, Sleight_of_Hand, Spellcraft, Stealth, Survival, Swim, Use_Magic_Device]



## Random draw by class from the available skill points as number of skills to draw
## Need to add weighting by Class skills, 90% for class skills and 10% for others
import random

barb_h_weight = 9
barb_l_weight = 1.4
barbarian_weighting = [9, 0.4, 0.4, 9, 9, .4, .4, .4, .4, .4, 9, .4, 9,.4, .4, .4, .4, .4, .4, 9, .4, .4, .4, .4, 9, .4, .4, 9, .4, .4, .4, .4, 9, 9, .4 
                      ]
barbarian_weighting = [int(barbarian_weighting) for barbarian_weighting in barbarian_weighting]

bard_h_weight = 3.2
bard_l_weight = 1.4
bard_weighting = [3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 1.4, 3.2, 3.2, 1.4, 1.4, 1.4, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 3.2, 1.4, 3.2, 3.2, 3.2, 3.2, 3.2, 1.4, 3.2
                 ]
bard_weighting = [int(bard_weighting) for bard_weighting in bard_weighting]

cleric_h_weight = 6.9
cleric_l_weight = .45
cleric_weighting = [.45, 6.9, .45, .45, 6.9, 6.9, .45, .45, .45, .45, .45, 6.9, .45, 6.9, .45, .45, .45, 6.9, .45, .45, 
                    6.9, 6.9, 6.9, 6.9, .45, .45, 6.9, .45, 6.9,.45, 6.9, .45, .45, .45, .45]
cleric_weighting = [int(cleric_weighting) for cleric_weighting in cleric_weighting]

druid_h_weight = 6.9
druid_l_weight = .45
druid_weighting = [.45, .45, .45, 6.9, 6.9, .45, .45, .45, .45, 6.9, 6.9, 6.9, .45, .45, .45, .45, 6.9, .45, .45, 6.9, .45, .45, .45, .45, 6.9, .45, 6.9, 6.9, .45, .45, 6.9, .45, 6.9, 6.9, .45
                  ]
druid_weighting = [int(druid_weighting) for druid_weighting in druid_weighting]

fighter_h_weight = 9
fighter_l_weight = 1.4
fighter_weighting = [1.4, 1.4, 1.4, 9, 9, 1.4, 1.4, 1.4, 1.4, 1.4, 9, 1.4, 9, 1.4, 9, 9, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 9, 9, 1.4, 1.4, 1.4, 1.4, 9, 9, 1.4
                    ]
fighter_weighting = [int(fighter_weighting) for fighter_weighting in fighter_weighting]

monk_h_weight = 6.4
monk_l_weight = .47
monk_weighting = [6.4, .47, .47, 6.4, 6.4, .47, .47, .47, 6.4, .47, .47, .47, 6.4, .47, .47, .47, .47, 6.4, .47, .47, .47, .47, 6.4, .47, 6.4, 6.4, 6.4, 6.4, 6.4, .47, .47, 6.4, .47, 6.4, .47]
monk_weighting = [int(monk_weighting) for monk_weighting in monk_weighting]

paladin_h_weight = 9
paladin_l_weight = 1.4
paladin_weighting = [1.4, 1.4, 1.4, 1.4, 9, 9, 1.4, 1.4, 1.4, 1.4, 9, 9, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 1.4, 9, 1.4, 9,1.4, 1.4, 1.4, 9, 9, 9, 1.4, 9, 1.4, 1.4, 1.4, 1.4
                    ]
paladin_weighting = [int(paladin_weighting) for paladin_weighting in paladin_weighting]

ranger_h_weight = 6
ranger_l_weight = .5
ranger_weighting = [.5, .5, .5, 6, 6, .5, .5, .5, .5, .5, 6, 6, 6, .5, 6, .5, 6, .5, .5, 6, .5, .5, .5, .5, 6, .5, 6, 6, .5, .5,6, 6, 6, 6, .5]
ranger_weighting = [int(ranger_weighting) for ranger_weighting in ranger_weighting]

rogue_h_weight = 4.2
rogue_l_weight = .71
rogue_weighting = [4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, 4.2, .71, .71, .71, 4.2, .71, 4.2, .71, .71, .71, 4.2, .71, .71, .71, .71, 4.2, 4.2, 4.2, 4.2, .71, 4.2, 4.2, .71, 4.2, .71, 4.2, 4.2]
rogue_weighting = [int(rogue_weighting) for rogue_weighting in rogue_weighting]

sorcerer_h_weight = 10
sorcerer_l_weight = .38
sorcerer_weighting = [.38, 10, 10, .38, 10, .38, .387, .38, .38, 10, .38, .38, 10, 10, .38, .38, .38, .38, .38, .38, .38, .38, .38, .38, .38, .38, 10, .38, .38, .38, 10, .38, .38, .38, 10]

sorcerer_weighting = [int(sorcerer_weighting) for sorcerer_weighting in sorcerer_weighting]

wizard_h_weight = 5.6
wizard_l_weight = .52
wizard_weighting = [.52, 5.6, .52, .52, 5.6, .52, .52, .52, .52, 5.6, .52, .52, .52, 5.6, 5.6, 5.6, 5.6, 5.6, 5.6, 5.6, 5.6, 5.6, 5.6, 5.6, .52, .52, 5.6, .52, .52, .52, 5.6, .52, .52, .52,.52
                   ]
wizard_weighting = [int(wizard_weighting) for wizard_weighting in wizard_weighting]
def random_draw(Class, class_weights):
    if Class == Class:
        Class_Draw = random.choices(skills_list_name, class_weights, k = Skill_Ranks)
        return Class_Draw
    else: 
        print("draw error")
Class_Draw = random_draw(Class, barbarian_weighting)
Class_Draw = random_draw(Class, bard_weighting)
Class_Draw = random_draw(Class, cleric_weighting)
Class_Draw = random_draw(Class, druid_weighting)
Class_Draw = random_draw(Class, fighter_weighting)
Class_Draw = random_draw(Class, monk_weighting)
Class_Draw = random_draw(Class, paladin_weighting)
Class_Draw = random_draw(Class, ranger_weighting)
Class_Draw = random_draw(Class, rogue_weighting)
Class_Draw = random_draw(Class, sorcerer_weighting)
Class_Draw = random_draw(Class, wizard_weighting)
        
## Cleaning the data so that the numerical values in Skill_List pulled from skills_list_value are integers and can 
## be added to the other calculated metrics
i=0
def Populate_Skills(Skill_String, Class_Draw, Skill_List):
    for i in Skill_List:
        Skill_List = i
    if [Skill_String] in Class_Draw:
        Skill_List = Skill_List + Class_Draw.count([Skill_String])  
    return Skill_List



Acrobatics = Populate_Skills('Acrobatics',  Class_Draw, Acrobatics)
Appraise = Populate_Skills('Appraise',  Class_Draw, Appraise)
Bluff = Populate_Skills('Bluff',  Class_Draw, Bluff)
Climb = Populate_Skills('Climb',  Class_Draw, Climb)
Craft = Populate_Skills('Craft',  Class_Draw, Craft)
Diplomacy = Populate_Skills('Diplomacy',  Class_Draw, Diplomacy)
Disable_Device = Populate_Skills('Disable_Device',  Class_Draw, Disable_Device)
Disguise = Populate_Skills('Disguise',  Class_Draw, Disguise)
Escape_Artist = Populate_Skills('Escape_Artist',  Class_Draw, Escape_Artist)
Fly = Populate_Skills('Fly',  Class_Draw, Fly)
Handle_Animal = Populate_Skills('Handle_Animal',  Class_Draw, Handle_Animal)
Heal = Populate_Skills('Heal',  Class_Draw, Heal)
Intimidate = Populate_Skills('Intimidate',  Class_Draw, Intimidate)
Knowledge_Arcana = Populate_Skills('Knowledge_Arcana',  Class_Draw, Knowledge_Arcana)
Knowledge_Dungeoneering = Populate_Skills('Knowledge_Dungeoneering',  Class_Draw, Knowledge_Dungeoneering)
Knowledge_Engineering = Populate_Skills('Knowledge_Engineering',  Class_Draw, Knowledge_Engineering)
Knowledge_Geography = Populate_Skills('Knowledge_Geography',  Class_Draw, Knowledge_Geography)
Knowledge_History = Populate_Skills('Knowledge_History',  Class_Draw, Knowledge_History)
Knowledge_Local = Populate_Skills('Knowledge_Local',  Class_Draw, Knowledge_Local)
Knowledge_Nature = Populate_Skills('Knowledge_Nature',  Class_Draw, Knowledge_Nature)
Knowledge_Nobility = Populate_Skills('Knowledge_Nobility',  Class_Draw, Knowledge_Nobility)
Knowledge_Planes = Populate_Skills('Knowledge_Planes',Class_Draw, Knowledge_Planes)
Knowledge_Religion = Populate_Skills('Knowledge_Religion',  Class_Draw, Knowledge_Religion)
Linguistics = Populate_Skills('Linguistics',  Class_Draw, Linguistics)
Perception = Populate_Skills('Perception',  Class_Draw, Perception)
Perform = Populate_Skills('Perform',  Class_Draw, Perform)
Profession = Populate_Skills('Profession',  Class_Draw, Profession)
Ride = Populate_Skills('Ride',  Class_Draw, Ride)
Sense_Motive = Populate_Skills('Sense_Motive',  Class_Draw, Sense_Motive)
Sleight_of_Hand = Populate_Skills('Sleight_of_Hand',  Class_Draw, Sleight_of_Hand)
Spellcraft = Populate_Skills('Spellcraft',  Class_Draw, Spellcraft)
Stealth = Populate_Skills('Stealth',  Class_Draw, Stealth)
Survival = Populate_Skills('Survival',  Class_Draw, Survival)
Swim = Populate_Skills('Swim',  Class_Draw, Swim)
Use_Magic_Device = Populate_Skills('Use_Magic_Device',  Class_Draw, Use_Magic_Device)

## Need to count the number of strings that are duplicates to create the final skill list.

Skills_Final = []
Skills_Final = pd.DataFrame(Skills_Final, columns = 
                              ["Acrobatics",  "Appraise", "Bluff", "Climb", "Craft", "Diplomacy", "Disable_Device", "Disguise", "Escape_Artist", "Fly",
      "Handle_Animal", "Heal", "Intimidate", "Knowledge_Arcana", "Knowledge_Dungeoneering", "Knowledge_Engineering", 
      "Knowledge_Geography", "Knowledge_History", "Knowledge_Local", "Knowledge_Nature", "Knowledge_Nobility", 
       "Knowledge_Planes", "Knowledge_Religion", "Linguistics", "Perception", "Perform", "Profession", "Ride", 
       "Sense_Motive", "Sleight_of_Hand", "Spellcraft", "Stealth", "Survival", "Swim", "Use_Magic_Device"])
Skills = pd.Series([Acrobatics,  Appraise, Bluff, Climb, Craft, Diplomacy, Disable_Device, Disguise, Escape_Artist, Fly,
      Handle_Animal, Heal, Intimidate, Knowledge_Arcana, Knowledge_Dungeoneering, Knowledge_Engineering, 
      Knowledge_Geography, Knowledge_History, Knowledge_Local, Knowledge_Nature, Knowledge_Nobility, 
       Knowledge_Planes, Knowledge_Religion, Linguistics, Perception, Perform, Profession, Ride, 
       Sense_Motive, Sleight_of_Hand, Spellcraft, Stealth, Survival, Swim, Use_Magic_Device], index = Skills_Final.columns)
Skills_Final = pd.DataFrame(Skills)
Skills_Final = Skills_Final.T
Skills_Final.head()
# Out:
# How many Dice would you like to roll?3
# How many sides will your dice have?6
# 13
# 10
# 15
# 10
# 8
# 11
# What race are you?Half-Orc
# Which ABS do you want to increase?STR
#    Str Mod  Dex Mod  Wis Mod  Cha Mod  Con Mod  Int Mod
# 0      2.0      2.0      0.0      0.0      0.0     -1.0
#    Acrobatics  Appraise  Bluff  Climb  Craft  Diplomacy  Disable_Device  \
# 0         2.0      -1.0    0.0    2.0   -1.0        0.0             2.0
#
#    Disguise  Escape_Artist  Fly        ...         Perform  Profession  Ride  \
# 0       0.0            2.0  2.0        ...             0.0         0.0   2.0
#
#    Sense_Motive  Sleight_of_Hand  Spellcraft  Stealth  Survival  Swim  \
# 0           0.0              2.0        -1.0      2.0       0.0   2.0
#
#    Use_Magic_Device
# 0               0.0
#
# [1 rows x 35 columns]

# %%
Ability_Scores.head()
# Out:
#                         Name  Class      Race Strength Charisma Dexterity  \
# 0  (Halungalon, Qropswunass)  Rogue  Half-Orc       15       10        15
#
#   Constitution Intelligence Wisdom    Size Gender Age Eye Color Hair Color  \
# 0           10            8     11  Medium   Male  33     Green      Brown
#
#   Languages   Height Weight
# 0  Half-Orc  8.33333    287

# %%
## Storing Lists for future use
## Barbarian_Top_Class_Skills =[Intimidate, Perception, Survival]
## Bard_Class_Top_Skills =[Appraise, Bluff, Diplomacy]
## Cleric_Class_Top_Skills = [Diplomacy, Heal, Knowledge_Religion]
## Druid_Class_Top_Skills = [Handle_Animal, Knowledge_Nature, Perception,]
## Fighter_Class_Top_Skills =[Climb, Survival, Swim]
## Monk_Class_Top_Skills = [Acrobatics, Escape_Artist, Perception]
## Paladin_Class_Top_Skills = [Diplomacy, Knowledge_Nobility, Sense_Motive]
## Ranger_Class_Top_Skills = [Knowledge_Geography, Perception, Survival]
## Rogue_Class_Top_Skills = [Disable_Device, Sleight_of_Hand, Stealth]
## Sorcerer_Class_Top_Skills = [Knowledge_Arcana, Spellcraft, Use_Magic_Device]
## Wizard_Class_Top_Skills = [Fly, Knowledge_Arcana, Spellcraft]


## Barbarian_Class_Less_Skills =[Acrobatics, Climb, Craft, Handle_Animal, Knowledge_Nature, Ride, Swim]
## Bard_Class_Less_Skills =[Acrobatics, Climb, Craft, Disguise, Escape_Artist, Intimidate, Knowledge_Arcana, Knowledge_Dungeoneering, Knowledge_Engineering, 
##      Knowledge_Geography, Knowledge_History, Knowledge_Local, Knowledge_Nature, Knowledge_Nobility, 
 ##      Knowledge_Planes, Knowledge_Religion, Linguistics, Perception, Perform, Profession, Sense_Motive, Sleight_of_Hand, Spellcraft, Stealth, Use_Magic_Device]
## Cleric_Class_Less_Skills = [Appraise, Craft, Knowledge_Arcana, Knowledge_History, Knowledge_Nobility, Knowledge_Planes,
##                      Linguistics, Profession, Sense_Motive, Spellcraft]
## Druid_Class_Less_Skills = [Climb, Craft, Fly, Heal, Knowledge_Geography,
##                     Profession, Ride, Spellcraft, Survival, Swim]
## Fighter_Class_Less_Skills =[Craft, Handle_Animal, Intimidate, Knowledge_Dungeoneering, Knowledge_Engineering, Profession, Ride]
## Monk_Class_Less_Skills = [Climb, Craft, Intimidate, Knowledge_History, Knowledge_Religion,
##                     Perform, Profession, Ride, Sense_Motive, Stealth, Swim]
## Paladin_Class_Less_Skills = [Craft, Handle_Animal, Heal,  Knowledge_Religion, Profession, Ride, Spellcraft]
## Ranger_Class_Less_Skills = [Climb, Craft, Handle_Animal, Heal, Intimidate, Knowledge_Dungeoneering, 
##                       Knowledge_Nature, Profession, Ride, Spellcraft, Stealth, Swim]
## Rogue_Class_Less_Skills = [Acrobatics, Appraise, Bluff, Climb, Craft, Diplomacy, Disguise, Escape_Artist, 
##                      Intimidate, Knowledge_Dungeoneering, Knowledge_Local, Linguistics, Perception, Perform, Profession, 
##                      Sense_Motive, Swim, Use_Magic_Device]
## Sorc_Class_Less_Skills = [Appraise, Bluff, Craft, Fly, Intimidate, Profession]
## Wizard_Class_Less_Skills = [Appraise, Craft, Knowledge_Dungeoneering, Knowledge_Engineering, 
##      Knowledge_Geography, Knowledge_History, Knowledge_Local, Knowledge_Nature, Knowledge_Nobility, 
##       Knowledge_Planes, Knowledge_Religion, Linguistics, Profession]
##
##Barbarian_Class_Skills =[Acrobatics, Climb, Craft, Handle_Animal, Intimidate, Knowledge_Nature, Perception, Ride, 
##                         Survival, Swim]
## Bard_Class_Skills =[Acrobatics, Appraise, Bluff, Climb, Craft, Diplomacy, Disguise, Escape_Artist, Intimidate, Knowledge_Arcana, Knowledge_Dungeoneering, Knowledge_Engineering, 
##      Knowledge_Geography, Knowledge_History, Knowledge_Local, Knowledge_Nature, Knowledge_Nobility, 
##       Knowledge_Planes, Knowledge_Religion, Linguistics, Perception, Perform, Profession, Sense_Motive, Sleight_of_Hand, Spellcraft, Stealth, Use_Magic_Device]
##Cleric_Class_Skills = [Appraise, Craft, Diplomacy, Heal, Knowledge_Arcana, Knowledge_History, Knowledge_Nobility, Knowledge_Planes,
##                      Knowledge_Religion, Linguistics, Profession, Sense_Motive, Spellcraft]
## Druid_Class_Skills = [Climb, Craft, Fly, Handle_Animal, Heal, Knowledge_Geography, Knowledge_Nature, Perception,
##                     Profession, Ride, Spellcraft, Survival, Swim]
## Fighter_Class_Skills =[Climb, Craft, Handle_Animal, Intimidate, Knowledge_Dungeoneering, Knowledge_Engineering, Profession, Ride, 
##                       Survival, Swim]
## Monk_Class_Skills = [Acrobatics, Climb, Craft, Escape_Artist, Intimidate, Knowledge_History, Knowledge_Religion, Perception, 
##                     Perform, Profession, Ride, Sense_Motive, Stealth, Swim]
## Paladin_Class_Skills = [Craft, Diplomacy, Handle_Animal, Heal, Knowledge_Nobility, Knowledge_Religion, Profession, Ride, 
##                        Sense_Motive, Spellcraft]
## Ranger_Class_Skills = [Climb, Craft, Handle_Animal, Heal, Intimidate, Knowledge_Dungeoneering, Knowledge_Geography, 
##                       Knowledge_Nature, Perception, Profession, Ride, Spellcraft, Stealth, Survival, Swim]
##Rogue_Class_Skills = [Acrobatics, Appraise, Bluff, Climb, Craft, Diplomacy, Disable_Device, Disguise, Escape_Artist, 
##                      Intimidate, Knowledge_Dungeoneering, Knowledge_Local, Linguistics, Perception, Perform, Profession, 
##                      Sense_Motive, Sleight_of_Hand, Stealth, Swim, Use_Magic_Device]
## Sorcerer_Class_Skills = [Appraise, Bluff, Craft, Fly, Intimidate, Knowledge_Arcana, Profession, Spellcraft, Use_Magic_Device]
## Wizard_Class_Skills = [Appraise, Craft, Fly, Knowledge_Arcana, Knowledge_Dungeoneering, Knowledge_Engineering, 
##      Knowledge_Geography, Knowledge_History, Knowledge_Local, Knowledge_Nature, Knowledge_Nobility, 
##       Knowledge_Planes, Knowledge_Religion, Linguistics, Profession, Spellcraft]
